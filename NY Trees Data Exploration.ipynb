# %%
import pandas as pd
import matplotlib.pyplot as plt

trees_data = pd.read_csv('C:/Users/Ahmad/Desktop/Python/Datasets/2015_Street_Tree_Census_-_Tree_Data.csv')
display(trees_data.head())
# Out:
#    tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status health  \
# 0   180683    348711  08/27/2015         3           0   OnCurb  Alive   Fair
# 1   200540    315986  09/03/2015        21           0   OnCurb  Alive   Fair
# 2   204026    218365  09/05/2015         3           0   OnCurb  Alive   Good
# 3   204337    217969  09/05/2015        10           0   OnCurb  Alive   Good
# 4   189565    223043  08/30/2015        21           0   OnCurb  Alive   Good
#
#                             spc_latin       spc_common  ...  boro_ct  \
# 0                         Acer rubrum        red maple  ...  4073900
# 1                   Quercus palustris          pin oak  ...  4097300
# 2  Gleditsia triacanthos var. inermis      honeylocust  ...  3044900
# 3  Gleditsia triacanthos var. inermis      honeylocust  ...  3044900
# 4                     Tilia americana  American linden  ...  3016500
#
#       state   latitude  longitude         x_sp         y_sp council district  \
# ...

# %%
trees_data.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
ny_trees = trees_data[['tree_id', 'tree_dbh', 'stump_diam',
       'curb_loc', 'status', 'health', 'spc_latin', 'steward','sidewalk', 
       'user_type', 'problems', 'root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other']]
ny_trees
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk  \
# 0                              Acer rubrum    None  NoDamage
# 1                        Quercus palustris    None    Damage
# ...

# %%
ny_trees.isna()
# Out:
#         tree_id  tree_dbh  stump_diam  curb_loc  status  health  spc_latin  \
# 0         False     False       False     False   False   False      False
# 1         False     False       False     False   False   False      False
# 2         False     False       False     False   False   False      False
# 3         False     False       False     False   False   False      False
# 4         False     False       False     False   False   False      False
# ...         ...       ...         ...       ...     ...     ...        ...
# 683783    False     False       False     False   False   False      False
# 683784    False     False       False     False   False   False      False
# 683785    False     False       False     False   False   False      False
# 683786    False     False       False     False   False   False      False
# 683787    False     False       False     False   False   False      False
#
# ...

# %%
ny_trees.isna().sum()
# Out:
# tree_id           0
# tree_dbh          0
# stump_diam        0
# curb_loc          0
# status            0
# health        31616
# spc_latin     31619
# steward       31615
# sidewalk      31616
# user_type         0
# problems      31664
# root_stone        0
# root_grate        0
# root_other        0
# trunk_wire        0
# trnk_light        0
# trnk_other        0
# brch_light        0
# brch_shoe         0
# brch_other        0
# dtype: int64

# %%
ny_trees.describe()
# Out:
#              tree_id       tree_dbh     stump_diam
# count  683788.000000  683788.000000  683788.000000
# mean   365205.011085      11.279787       0.432463
# std    208122.092902       8.723042       3.290241
# min         3.000000       0.000000       0.000000
# 25%    186582.750000       4.000000       0.000000
# 50%    366214.500000       9.000000       0.000000
# 75%    546170.250000      16.000000       0.000000
# max    722694.000000     450.000000     140.000000

# %%
ny_trees.hist(bins=60)
# Out:
# array([[<AxesSubplot:title={'center':'tree_id'}>,
#         <AxesSubplot:title={'center':'tree_dbh'}>],
#        [<AxesSubplot:title={'center':'stump_diam'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
big_trees = ny_trees[ny_trees['tree_dbh'] > 50]
big_trees.plot(kind='scatter', y='tree_dbh', x='tree_id', figsize=(15,7.5))
plt.show()

# %%
big_stumps = ny_trees[ny_trees['stump_diam'] > 50]
big_stumps.plot(kind='scatter', x='tree_id', y='stump_diam', figsize=(15, 7.5))
# Out:
# <AxesSubplot:xlabel='tree_id', ylabel='stump_diam'>

# %%
pd.DataFrame(ny_trees['spc_latin'].value_counts())
# Out:
#                                     spc_latin
# Platanus x acerifolia                   87014
# Gleditsia triacanthos var. inermis      64264
# Pyrus calleryana                        58931
# Quercus palustris                       53185
# Acer platanoides                        34189
# ...                                       ...
# Pinus nigra                                37
# Pinus rigida                               33
# Maclura pomifera                           29
# Pinus sylvestris                           25
# Pinus virginiana                           10
#
# [132 rows x 1 columns]

# %%
pd.DataFrame(ny_trees['spc_latin'].value_counts()).plot(kind='bar', figsize=(15,7.5))
# Out:
# <AxesSubplot:>

# %%
ny_trees['health'].value_counts()
# Out:
# Good    528850
# Fair     96504
# Poor     26818
# Name: health, dtype: int64

# %%
ny_trees['steward'].value_counts()
# Out:
# None       487823
# 1or2       143557
# 3or4        19183
# 4orMore      1610
# Name: steward, dtype: int64

# %%
ny_trees['sidewalk'].value_counts()
# Out:
# NoDamage    464978
# Damage      187194
# Name: sidewalk, dtype: int64

# %%
ny_trees['status'].value_counts()
# Out:
# Alive    652173
# Stump     17654
# Dead      13961
# Name: status, dtype: int64

# %%
ny_trees['curb_loc'].value_counts()
# Out:
# OnCurb            656896
# OffsetFromCurb     26892
# Name: curb_loc, dtype: int64

# %%
stumps = ny_trees[ny_trees['status'] == 'Stump']
stumps
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 37       211205         0          16   OnCurb  Stump    NaN       NaN
# 239      203597         0          15   OnCurb  Stump    NaN       NaN
# 641      179766         0          30   OnCurb  Stump    NaN       NaN
# 644      180619         0          10   OnCurb  Stump    NaN       NaN
# 646      208828         0          15   OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...      ...    ...    ...       ...
# 683348   152836         0          13   OnCurb  Stump    NaN       NaN
# 683686   191219         0          25   OnCurb  Stump    NaN       NaN
# 683695   170888         0           5   OnCurb  Stump    NaN       NaN
# 683697   177922         0          17   OnCurb  Stump    NaN       NaN
# 683699   172660         0           4   OnCurb  Stump    NaN       NaN
#
#        steward sidewalk         user_type problems root_stone root_grate  \
# ...

# %%
deads = ny_trees[ny_trees['status'] == 'Dead']
deads
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 266      210544         6           0          OnCurb   Dead    NaN       NaN
# 285      188609         9           0          OnCurb   Dead    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 682816   184342        11           0          OnCurb   Dead    NaN       NaN
# 682823   155430         2           0          OnCurb   Dead    NaN       NaN
# 683346   156566        10           0          OnCurb   Dead    NaN       NaN
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
#
# ...

# %%
len(deads+stumps)
# Out:
# 31615

# %%
ny_trees.columns
# Out:
# Index(['tree_id', 'tree_dbh', 'stump_diam', 'curb_loc', 'status', 'health',
#        'spc_latin', 'steward', 'sidewalk', 'user_type', 'problems',
#        'root_stone', 'root_grate', 'root_other', 'trunk_wire', 'trnk_light',
#        'trnk_other', 'brch_light', 'brch_shoe', 'brch_other'],
#       dtype='object')

# %%
tree_problems = ny_trees[['root_stone', 'root_grate', 'root_other', 'trunk_wire',
       'trnk_light', 'trnk_other', 'brch_light', 'brch_shoe', 'brch_other']]
tree_problems
# Out:
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 683783         No         No         No         No         No         No
# 683784         No         No         No         No         No         No
# 683785         No         No         No         No         No         No
# 683786         No         No         No         No         No         No
# 683787         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 0              No        No         No
# ...

# %%
tree_problems.apply(pd.Series.value_counts)
# Out:
#      root_stone  root_grate  root_other  trunk_wire  trnk_light  trnk_other  \
# No       543789      680252      653466      670514      682757      651215
# Yes      139999        3536       30322       13274        1031       32573
#
#      brch_light  brch_shoe  brch_other
# No       621423     683377      659433
# Yes       62365        411       24355

# %%
mask =  ((ny_trees.status == 'Dead') | (ny_trees.status == 'Stump'))
ny_trees.loc[mask] = ny_trees.loc[mask].fillna("Not Applicable")

# %%
ny_trees[ny_trees['status'] == 'Dead']
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status          health  \
# 57       187807         0           0          OnCurb   Dead  Not Applicable
# 196      208322        10           0          OnCurb   Dead  Not Applicable
# 209      209058         6           0          OnCurb   Dead  Not Applicable
# 266      210544         6           0          OnCurb   Dead  Not Applicable
# 285      188609         9           0          OnCurb   Dead  Not Applicable
# ...         ...       ...         ...             ...    ...             ...
# 682816   184342        11           0          OnCurb   Dead  Not Applicable
# 682823   155430         2           0          OnCurb   Dead  Not Applicable
# 683346   156566        10           0          OnCurb   Dead  Not Applicable
# 683693   156162         3           0  OffsetFromCurb   Dead  Not Applicable
# 683698   193791         3           0          OnCurb   Dead  Not Applicable
#
# ...

# %%
ny_trees.isna().sum()
# Out:
# tree_id        0
# tree_dbh       0
# stump_diam     0
# curb_loc       0
# status         0
# health         1
# spc_latin      5
# steward        0
# sidewalk       1
# user_type      0
# problems      49
# root_stone     0
# root_grate     0
# root_other     0
# trunk_wire     0
# trnk_light     0
# trnk_other     0
# brch_light     0
# brch_shoe      0
# brch_other     0
# dtype: int64

# %%
ny_trees['health'].fillna("Good", inplace=True)
ny_trees['spc_latin'].fillna("Unknown", inplace=True)
ny_trees['steward'].fillna("None", inplace=True)
ny_trees['sidewalk'].fillna("NoDamage", inplace=True)
ny_trees['problems'].fillna("None", inplace=True)
# Out:
# C:\Users\Ahmad\AppData\Local\Temp\ipykernel_18900\2506628303.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ny_trees['health'].fillna("Good", inplace=True)
# C:\Users\Ahmad\AppData\Local\Temp\ipykernel_18900\2506628303.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ny_trees['spc_latin'].fillna("Unknown", inplace=True)
# C:\Users\Ahmad\AppData\Local\Temp\ipykernel_18900\2506628303.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
ny_trees.isna().sum()
# Out:
# tree_id       0
# tree_dbh      0
# stump_diam    0
# curb_loc      0
# status        0
# health        0
# spc_latin     0
# steward       0
# sidewalk      0
# user_type     0
# problems      0
# root_stone    0
# root_grate    0
# root_other    0
# trunk_wire    0
# trnk_light    0
# trnk_other    0
# brch_light    0
# brch_shoe     0
# brch_other    0
# dtype: int64

# %%
ny_trees['health'].value_counts()
# Out:
# Good              528851
# Fair               96504
# Not Applicable     31615
# Poor               26818
# Name: health, dtype: int64

# %%
large_trees = ny_trees[(ny_trees.stump_diam > 60) | (ny_trees.tree_dbh > 60)]
large_trees.shape
# Out:
# (245, 20)

# %%
ny_trees = ny_trees[(ny_trees.stump_diam <= 60) & (ny_trees.tree_dbh <= 60)]
ny_trees.shape
# Out:
# (683543, 20)

# %%
ny_trees_alive = ny_trees[ny_trees.status == 'Alive']
ny_trees_dead_or_stump = ny_trees[(ny_trees.status == 'Dead') & (ny_trees.status == 'Stump')]

# %%
stats_alive = ny_trees_alive.groupby('spc_latin')['tree_dbh'].describe().reset_index()[['spc_latin', '25%', '75%']]
stats_alive
# Out:
#              spc_latin  25%   75%
# 0                 Acer  7.0  15.0
# 1    Acer buergerianum  5.0  10.0
# 2       Acer campestre  4.0   9.0
# 3         Acer ginnala  4.0  10.0
# 4         Acer griseum  2.0   3.0
# ..                 ...  ...   ...
# 128    Ulmus americana  4.0  17.0
# 129   Ulmus parvifolia  3.0  10.0
# 130       Ulmus pumila  4.0  17.0
# 131            Unknown  4.0  11.0
# 132    Zelkova serrata  4.0  11.0
#
# [133 rows x 3 columns]

# %%
ny_trees_alive.merge(stats_alive, on='spc_latin', how='left') 
ny_trees_alive
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk  \
# 0                              Acer rubrum    None  NoDamage
# 1                        Quercus palustris    None    Damage
# ...
